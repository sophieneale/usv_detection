# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import os

import usv_library as ul
import usv_class as uc
from usv_class import USV
import setup

# %%
base_path = 'USV_DATA'
session_id = 'SK5aSK1b_Restrainer_Experiment_Other_d6_s2_04232025_nontether'
usv_type = '40kHz' 
params_file = "25kHz_with_trial_starts"

# %%
setup.path_lookup(base_path, session_id, usv_type, params_file)
# Out:
# Path exists: USV_DATA/SK5aSK1b_Restrainer_Experiment_Other_d6_s2_04232025_nontether/40kHz/25kHz_with_trial_starts
# Path folder is empty. Ready to populate.
