# %% [markdown]
# # USV Processing notebook for running detection
# Before running the cells in this notebook, please refer to this checklist:
#
# - Activate usvprocessing environment prior to running code -- load from environment.yml
# - Ensure the session files stored on your local device are:
#     - in the correct format
#     - located in the _wavfiles_ folder

# %% [markdown]
# # 1. Initial Setup
# This section only needs to be run __once__
# ## Load imports

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import os

import usv_library as ul
import usv_class as uc
from usv_class import USV
import setup

# %% [markdown]
# ### Establish path names

# %%
# Set path variables:
repo_path = os.getcwd()
USV_DATA_path = os.path.join(repo_path, 'USV_DATA')
wavfiles_path = os.path.join(repo_path, 'wavfiles')

# %% [markdown]
# ## Set personal parameters
#
# Run __once__ at the beginning of your validation/extraction session
# > In this step you will:
# - Set your rater ID (first and last inital)
# - Set your desired frequency range
#
# #### Select frequency range from the following options:
# >A) 20 kHz (20,000 --> 30,000 Hz)
# >B) 40 kHz (40,000 --> 90,000 Hz)

# %%
# Set rater ID
rater_id = setup.enter_rater_id()

# Set frequency range and parent directory
freq_range, freq_dir = setup.enter_freq_range()
USV_DATA_subpath = os.path.join(USV_DATA_path, freq_dir)
# Out:
# Enter rater ID (first/last initials): ('quit' to exit) YO
# Rater ID set to: YO
# Which frequency range are you rating? (A) 20kHz or (B) 40kHz: ('quit' to exit) B
# Frequency range set to: (40000, 90000)

# %% [markdown]
# ### View sessions with local data

# %%
# View session folders in wavfiles directory for easy access
pd.set_option('display.max_colwidth', None)
pd.DataFrame({"session_folder":
              [subdir for subdir in os.listdir(wavfiles_path) if not subdir.endswith('.txt')]})
# Out:
#                                                       session_folder
# 0                                                           .gitkeep
# 1   SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day10Session1_02112026_JW
# 2   SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day10Session2_02112026_JW
# 3   SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO
# 4   SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session2_02202026_YO
# 5   SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day16Session1_02242026_YO
# 6   SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day16Session2_02242026_YO
# 7    SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day1Session1_01272026_YO
# 8    SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day1Session2_01272026_YO
# 9    SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day1Session3_01272026_YO
# 10   SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day5Session1_02032026_YO
# 11   SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day5Session2_02032026_YO

# %% [markdown]
# ---
# <div style="text-align: center;">
#
# >
# #### Only run the above code once! (Unless you are switching the frequency range you are validating or resetting your ID)

# %% [markdown]
# # 2. Execution

# %% [markdown]
# ## Enter the session ID and verify WAV file exists

# %%
# Session ID entry
session_id = setup.get_input("Session ID", "Enter the session name: ")
print(f"Session ID entered: {session_id} \n")

# Look for WAV file -- both detection and verification need it
wavfile = os.path.join(wavfiles_path, session_id, "Dodotronic Track.wav")
if not os.path.exists(wavfile):
    raise FileNotFoundError(f"WAV file not found, cannot continue. Missing: {wavfile}")
else:
    print(f"WAV file found: {wavfile}")
    print("Open in Audacity")
# Out:
# Enter the session name:  ('quit' to exit) SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO
# Session ID entered: SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO
#
# WAV file found: C:\Users\User\usv_detection\wavfiles\SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO\Dodotronic Track.wav
# Open in Audacity

# %%
# Check for a trial starts file (having this file is optional)
trial_starts, trial_starts_rater = setup.get_trial_starts(wavfiles_path, session_id)
if trial_starts is not None:
    print(f"File name: {trial_starts}")
# Out:
# Trial starts file found.
# File name: trial_starts.csv

# %% [markdown]
# ## Detection/validation
# #### Open the WAV file in Audacity and run the next section
# What do the following code blocks do?
# - Check if labels already exist for your chosen file
#     - If so: move onto validation
#     - If not: run detection

# %%
# Check if session has been processed before: check for labels / rater
labels_exist = setup.search_labels(USV_DATA_subpath, session_id)
existing_rater = setup.check_existing_rater(USV_DATA_subpath, session_id, rater_id)
# Out:
# Folder for SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO not found in USV_DATA directory.
# Run USV detection to create the folder and files.

# %%
# Checks if labels exist before running USV detection
if not labels_exist:
    if trial_starts is not None:
        trial_starts_file = os.path.join('wavfiles/', session_id, trial_starts)
        offset = setup.get_offset(trial_starts_file)
        print(f"Offset applied: {offset} seconds")
        usv = USV(wavfile, session_id, trial_starts_file, offset)
    else:
        usv = USV(wavfile, session_id)

    usv.run_setup(freq_range, USV_DATA_path, freq_dir) 
    usv.run_usv_detection(freq_range)

    print(f"Labels saved as: {session_id}_USV_aud.txt")
# Out:
#      Event  Timestamp
# 0  T_start    55.5678
# 1  T_start   474.0930
# 2  T_start   894.7510
# 3  T_start  1356.4300
# Enter plexon beep time in seconds to align trials:  ('quit' to exit) 22.360875
# Enter audacity beep time in seconds:  ('quit' to exit) 19.173
# Offset applied: 3.187875000000002 seconds
# C:\Users\User\usv_detection\USV_DATA\40kHz\SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO
# Folder for SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO created in USV_DATA\40kHz. Setting default parameters...
# Default parameters loaded from default_params/40kHz_with_trial_starts.json for SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO.
# Thresholds in the 40.0-90.0 kHz range              for SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO have been set, beginning USV detection...
# usv detection complete... storing usvs
# Additional columns added for SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO!
# Embeddings added for SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO!
# Getting session data for SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO!
# Parameters exported for SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO!
# CSV files stored for SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO!
# Audacity labels exported for SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO!
# run_usv_detection complete!
# Labels saved as: SK4ASK4BSK2ASK2B_USVBehaviorExperiment_Day15Session1_02202026_YO_USV_aud.txt

# %%
if not existing_rater:
    raise Exception(f"{session_id} has already been rated by {rater_id}.")

if not input("Proceed to USV validation/sorting? (y/n): ").lower().startswith('y'):
    raise Exception("Process terminated by user.")

# Runs sorting/validation on USV data (preexisting or newly detected)
session_data = os.path.join(USV_DATA_subpath, session_id)
usv_csv = os.path.join(session_data, f"{session_id}_USV.csv")
call_lst = ul.validate_usv(usv_csv, freq_dir)
pd.DataFrame(call_lst).to_csv(os.path.join(session_data, f"{session_id}_USV_rated_{rater_id}.csv"), index=False)
print("USV validation/sorting complete. Rated file added to session folder.")
# Out:
# Proceed to USV validation/sorting? (y/n):  y
# Is USV_1 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 0, max = 2573):  9
# Is USV_10 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_11 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_12 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_13 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_14 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_15 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_16 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_17 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_18 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_19 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_20 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_21 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_22 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_23 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 22, max = 2573):  27
# Is USV_28 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_29 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_30 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_31 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_32 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_33 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_34 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_35 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_36 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_37 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_38 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_39 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_40 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_41 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_42 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_43 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_44 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_45 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_46 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_47 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_48 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_49 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_50 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_51 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_52 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_53 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_54 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_55 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_56 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_57 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_58 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_59 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_60 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_61 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_62 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_63 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_64 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_65 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_66 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_67 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_68 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_69 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_70 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_71 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_72 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_73 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_74 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_75 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_76 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_77 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_78 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_79 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 78, max = 2573):  88
# Is USV_89 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_90 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_91 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_92 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 91, max = 2573):  150
# Is USV_151 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_152 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 151, max = 2573):  295
# Is USV_296 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_297 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_298 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_299 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_300 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_301 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_302 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_303 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 302, max = 2573):  306
# Is USV_307 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_308 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 307, max = 2573):  410
# Is USV_411 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_412 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 411, max = 2573):  520
# Is USV_521 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_522 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_523 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_524 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_525 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_526 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_527 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_528 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_529 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_530 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_531 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_532 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_533 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_534 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_535 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_536 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_537 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_538 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_539 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 538, max = 2573):  576
# Is USV_577 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_578 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 577, max = 2573):  588
# Is USV_589 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_590 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 589, max = 2573):  686
# Is USV_687 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_688 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 687, max = 2573):  713
# Is USV_714 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_715 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_716 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  2
# Is USV_717 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_718 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 717, max = 2573):  775
# Is USV_776 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_777 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_778 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  11
# Invalid input. Enter 1, 2, 'skip', or 'exit'.
# Is USV_778 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_779 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV_780 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  skip
# Skip to which index? (current = 779, max = 2573):  827
# Is USV_828 a USV? (1 = yes, 2 = no, skip = jump, exit = stop):  1
# Is USV